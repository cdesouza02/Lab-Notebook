# %%
getwd()
# Out:
# [1] "/Users/carolinedesouza/Documents/SCTLD/Lab-Notebook/Coral-Lab-Notebook"

# %%
 setwd("C:/carolinedesouza/Carolines-MacBook-Pro-3/Documents") 
    a <- read.csv("PAN-BDT_ColonyData_copy.csv")
# Out:
# Error in setwd("C:/carolinedesouza/Carolines-MacBook-Pro-3/Documents"): cannot change working directory
# Traceback:
#
# 1. setwd("C:/carolinedesouza/Carolines-MacBook-Pro-3/Documents")

# %%
a <- read.csv("PAN-BDT_ColonyData_copy.csv")

# %%
read.csv("PAN-BDT_ColonyData_copy.csv")
# Out:
#     X   Date_initial_tag Transect        Transect_num Current_tag_num Species
# 1    1  9/10/22          STRI Reef       1             1              SSID
# 2    2  9/10/22          STRI Reef       1             2              MCAV
# 3    3  9/10/22          STRI Reef       1             3              SSID
# 4    4  9/10/22          STRI Reef       1             4              ORBI
# 5    5  9/10/22          STRI Reef       1             5              CNAT
# 6    6  9/10/22          STRI Reef       1             6              CNAT
# 7    7  9/10/22          STRI Reef       1             7              SSID
# 8    8  9/10/22          STRI Reef       1             8              MCAV
# 9    9  9/10/22          STRI Reef       1             9              SSID
# 10  10  9/10/22          STRI Reef       1            10              SSID
# 11  11  9/10/22          STRI Reef       1            11              MCAV
# ...
